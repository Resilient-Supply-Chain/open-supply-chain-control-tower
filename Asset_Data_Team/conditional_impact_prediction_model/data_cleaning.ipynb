# %% [markdown]
# ### This notebook is designed to combine and cleaning power outage customer imapct data (Y) and weather related predictor data (X)

# %% [markdown]
# #### 1. Prepare Y data

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Read and combine customer impact data
impact_2022 = pd.read_csv('raw_data/eaglei_outages_with_events_2022.csv')
impact_2023 = pd.read_csv('raw_data/eaglei_outages_with_events_2023.csv')
impact = pd.concat([impact_2022, impact_2023], ignore_index=True)

# Convert datetime column
impact['start_time'] = pd.to_datetime(impact['start_time'])

print(f"Combined data shape: {impact.shape}")
impact.head()
# Out:
# Combined data shape: (172194, 14)
#     event_id state_event Datetime Event Began Datetime Restoration  \
# 0  Alabama-0     Alabama  2022-01-03 01:00:00  2022-01-03 14:00:00
# 1  Alabama-0     Alabama  2022-01-03 01:00:00  2022-01-03 14:00:00
# 2  Alabama-0     Alabama  2022-01-03 01:00:00  2022-01-03 14:00:00
# 3  Alabama-0     Alabama  2022-01-03 01:00:00  2022-01-03 14:00:00
# 4  Alabama-0     Alabama  2022-01-03 01:00:00  2022-01-03 14:00:00
#
#        Event Type  fips    state   county          start_time  duration  \
# 0  Severe Weather  1001  Alabama  Autauga 2022-01-03 04:00:00      5.75
# 1  Severe Weather  1003  Alabama  Baldwin 2022-01-03 13:45:00      3.00
# 2  Severe Weather  1005  Alabama  Barbour 2022-01-03 03:45:00     11.50
# 3  Severe Weather  1007  Alabama     Bibb 2022-01-03 03:00:00      2.50
# 4  Severe Weather  1009  Alabama   Blount 2022-01-03 03:45:00      2.00
#
#               end_time  min_customers  max_customers  mean_customers
# 0  2022-01-03 09:45:00            452            723      583.478261
# 1  2022-01-03 16:45:00            738           1404     1096.666667
# 2  2022-01-03 15:15:00            208            979      570.826087
# 3  2022-01-03 05:30:00            252            254      252.400000
# 4  2022-01-03 05:45:00            295            299      296.875000

# %%
# Filter for California severe weather (Dec 2022 - Mar 2023)
# We can expand by using other States' training data for accuracy improvement later
impact_filtered = impact[
    (impact['state_event'] == 'California') & 
    (impact['Event Type'] == 'Severe Weather') & 
    (impact['start_time'] >= '2022-12-01') & 
    (impact['start_time'] <= '2023-03-31')
]
impact_filtered["start_date"] = impact_filtered['start_time'].dt.floor('D')
#impact_filtered = impact_filtered[["start_date", "county", "duration", "mean_customers"]]
impact_filtered = impact_filtered[["start_date", "county", "mean_customers"]]
# Out:
# /var/folders/yk/dpbmrr3541xcv9jkz422gf0r0000gn/T/ipykernel_20824/266098259.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   impact_filtered["start_date"] = impact_filtered['start_time'].dt.floor('D')

# %%
impact_filtered.head(5)
# Out:
#      start_date           county  mean_customers
# 6806 2022-12-31           Amador     2693.000000
# 6807 2022-12-31        El Dorado     1321.333333
# 6808 2022-12-31             Napa     1205.000000
# 6809 2022-12-31       Sacramento      207.250000
# 6810 2022-12-31  San Luis Obispo      512.666667

# %%
impact_filtered.shape
# Out:
# (381, 3)

# %%
# Agg to county-date level
impact_agg = impact_filtered.groupby(["start_date", "county"]).sum().reset_index()
impact_agg.rename(columns={"mean_customers": "total_customers", "start_date": "date"}, inplace=True)
impact_agg.head(20)
# Out:
#          date           county  total_customers
# 0  2022-12-31           Amador      2693.000000
# 1  2022-12-31        El Dorado      1321.333333
# 2  2022-12-31             Napa      1205.000000
# 3  2022-12-31       Sacramento       207.250000
# 4  2022-12-31  San Luis Obispo       512.666667
# 5  2022-12-31           Solano       365.625000
# 6  2022-12-31           Sonoma       585.666667
# 7  2023-01-07         Monterey      1660.985294
# 8  2023-01-07      San Joaquin       948.500000
# 9  2023-01-07           Tehama       392.583333
# 10 2023-01-08          Alameda       721.154545
# 11 2023-01-08           Amador      7078.470629
# 12 2023-01-08            Butte      3888.184343
# 13 2023-01-08        Calaveras      4727.796591
# 14 2023-01-08     Contra Costa      8121.066667
# 15 2023-01-08        Del Norte      1653.000000
# 16 2023-01-08        El Dorado     15055.651049
# 17 2023-01-08           Fresno      2396.764817
# 18 2023-01-08         Humboldt      2857.118182
# 19 2023-01-08             Kern      1129.720000

# %%
impact_agg.shape
# Out:
# (224, 3)

# %% [markdown]
# #### 2. Preapre X data

# %%
predictor = pd.read_csv('raw_data/california_risk_model_data_dec2022_mar2023.csv')
predictor.rename(columns = {"county_name": "county"}, inplace = True)
predictor["date"] = pd.to_datetime(predictor["date"])
predictor["date"] = predictor['date'].dt.floor('D')

# %%
predictor.shape
# Out:
# (7018, 36)

# %%
predictor.head(5)
# Out:
#    county_code   county       date     ivt_max ar_intensity  gage_height_mean  \
# 0         6001  Alameda 2022-12-01  517.876160          AR2          3.363378
# 1         6001  Alameda 2022-12-02  231.908783          NaN          3.363423
# 2         6001  Alameda 2022-12-03  456.337891          AR1          3.365482
# 3         6001  Alameda 2022-12-04  550.994995          AR2          3.800255
# 4         6001  Alameda 2022-12-05  330.216705          AR1          3.439359
#
#    streamflow_mean  wind_speed_max  wind_gust_max  precip_total  runoff_total  \
# 0         8.844656       10.958761      28.427376      3.846169      0.067472
# 1         9.136874        6.120897      11.851345      0.020504      0.000238
# 2         7.298010        5.717101       9.304350      0.570774      0.009298
# 3        41.210267        6.267160      22.702106      1.450539      0.032067
# 4         8.097739        6.848634      18.281908      0.118732      0.001907
#
#    temp_anomaly  soil_moisture_mean     IVT_max  IVT_duration AR_category  \
# 0      2.004796            0.180444  517.876160            12         AR2
# 1     -2.666713            0.343442  231.908783             0         NaN
# 2     -2.150843            0.315793  456.337891            12         AR1
# 3      0.536351            0.388857  550.994995            12         AR2
# 4      3.223302            0.352034  330.216705            12         AR1
#
#    Precip_24h  Precip_72h  Wind_gust_max  Soil_moisture_pct    API_7d  \
# 0    3.846169    3.846169      28.427376           0.180444  3.846169
# 1    0.020504    3.866673      11.851345           0.343442  3.482056
# 2    0.570774    4.437447       9.304350           0.315793  3.666162
# 3    1.450539    2.041817      22.702106           0.388857  4.672956
# 4    0.118732    2.140045      18.281908           0.352034  4.202890
#
#     API_14d  Snowpack_SWE  Temp_anomaly  Streamflow_pct  \
# 0  3.846169            80      2.004796          56.250
# 1  3.674364            80     -2.666713          59.375
# 2  4.051805            80     -2.150843          46.875
# 3  5.280471            80      0.536351          78.125
# 4  5.104804            80      3.223302          53.125
#
#    Streamflow_p95_exceed  Runoff_ratio  Flood_stage_exceed  AR_count_7d  \
# 0              -0.990279      0.017543                   0          1.0
# 1              -0.989958      0.011628                   0          1.0
# 2              -0.991979      0.016291                   0          2.0
# 3              -0.954708      0.022107                   0          3.0
# 4              -0.991100      0.016064                   0          4.0
#
#    AR_count_14d  Wet_days_10  Dry_gap  Population_exposed  \
# 0           1.0          1.0        0              100000
# 1           1.0          1.0        1              100000
# 2           2.0          1.0        2              100000
# 3           3.0          2.0        0              100000
# 4           4.0          2.0        1              100000
#
#    Infrastructure_density  County_area  Agricultural_share
# 0                     2.0         5000                0.45
# 1                     2.0         5000                0.45
# 2                     2.0         5000                0.45
# 3                     2.0         5000                0.45
# 4                     2.0         5000                0.45

# %%
primary_table = impact_agg.merge(
    predictor, 
    left_on=['county', 'date'], 
    right_on=['county', 'date'],
    how='left'
)

print(f"Merged data shape: {primary_table.shape}")
primary_table.head()
# Out:
# Merged data shape: (224, 37)
#         date           county  total_customers  county_code      ivt_max  \
# 0 2022-12-31           Amador      2693.000000         6005   781.385925
# 1 2022-12-31        El Dorado      1321.333333         6017   612.015625
# 2 2022-12-31             Napa      1205.000000         6055  1174.133789
# 3 2022-12-31       Sacramento       207.250000         6067  1035.189819
# 4 2022-12-31  San Luis Obispo       512.666667         6079   752.332153
#
#   ar_intensity  gage_height_mean  streamflow_mean  wind_speed_max  \
# 0          AR3               NaN              NaN       16.213619
# 1          AR2          6.725536       501.512348       16.793095
# 2          AR4         12.444826      1326.107639       12.255922
# 3          AR4         15.933702     11063.678186       15.634851
# 4          AR3          7.198949        72.212894       13.706140
#
#    wind_gust_max  precip_total  runoff_total  temp_anomaly  \
# 0      36.041809     17.823219      4.023075      5.834319
# 1      46.787708     24.123669      5.789280      5.107599
# 2      37.610329      3.623009      0.169039      5.680211
# 3      28.197020     14.045238      3.161669      6.739041
# 4      33.783848      0.730991      0.014067      4.653655
#
#    soil_moisture_mean      IVT_max  IVT_duration AR_category  Precip_24h  \
# 0            0.476011   781.385925            12         AR3   17.823219
# 1            0.514730   612.015625            12         AR2   24.123669
# 2            0.410417  1174.133789            12         AR4    3.623009
# 3            0.437250  1035.189819            12         AR4   14.045238
# 4            0.404371   752.332153            12         AR3    0.730991
#
#    Precip_72h  Wind_gust_max  Soil_moisture_pct     API_7d    API_14d  \
# 0   24.079323      36.041809           0.476011  29.768515  32.117653
# 1   31.211853      46.787708           0.514730  38.038540  40.787506
# 2    5.913258      37.610329           0.410417   8.080816   9.077239
# 3   18.409252      28.197020           0.437250  23.039103  24.982715
# 4    0.884533      33.783848           0.404371   2.598190   3.055525
#
#    Snowpack_SWE  Temp_anomaly  Streamflow_pct  Streamflow_p95_exceed  \
# 0            20      5.834319             NaN               0.000000
# 1            80      5.107599          96.875               0.940605
# 2            80      5.680211          96.875               0.459083
# 3            80      6.739041          96.875               0.350062
# 4            20      4.653655          84.375              -0.889952
#
#    Runoff_ratio  Flood_stage_exceed  AR_count_7d  AR_count_14d  Wet_days_10  \
# 0      0.225721                   0          4.0           4.0          4.0
# 1      0.239983                   1          4.0           4.0          4.0
# 2      0.046657                   1          4.0           4.0          3.0
# 3      0.225106                   1          3.0           3.0          3.0
# 4      0.019243                   0          5.0           5.0          2.0
#
#    Dry_gap  Population_exposed  Infrastructure_density  County_area  \
# 0        0               30000                     2.0         3000
# 1        0               30000                     2.0         3000
# 2        0               30000                     2.0         3000
# 3        0               30000                     2.0         3000
# 4        3              240000                     5.0         8000
#
#    Agricultural_share
# 0                0.35
# 1                0.35
# 2                0.35
# 3                0.35
# 4                0.15

# %%
primary_table.to_csv("cleaned_primary_table/conditional_impact_primary_table.csv", index=False)
